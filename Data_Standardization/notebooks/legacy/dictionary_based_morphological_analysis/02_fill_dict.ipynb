# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Install and import packages

# %%
# !pip install jamo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import pandas as pd
import jamo
from jamo import h2j, j2hcj

# %% [markdown]
# # 2. Define the final-consonant (jongseong) function

# %%
def get_jongsung_TF(sample_text):
    sample_text_list = list(sample_text)
    last_word = sample_text_list[-1]
    last_word_jamo_list = list(j2hcj(h2j(last_word)))
    last_jamo = last_word_jamo_list[-1]

    jongsung_TF = "T"

    if last_jamo in ['ㅏ', 'ㅑ', 'ㅓ', 'ㅕ', 'ㅗ', 'ㅛ', 'ㅜ', 'ㅠ', 'ㅡ', 'ㅣ', 'ㅘ', 'ㅚ', 'ㅙ', 'ㅝ', 'ㅞ', 'ㅢ', 'ㅐ,ㅔ', 'ㅟ', 'ㅖ', 'ㅒ']:
        jongsung_TF = "F"

    return jongsung_TF

# %% [markdown]
# # 3. Apply the jongseong function

# %%
# Load data
dict_notf = pd.read_csv('/content/drive/MyDrive/menu_labelling/dictionaries/dict1_v1_0.csv')
dict_notf.head()
# Out:
#   <surface>  <left_context_id>  <right_context_id>  <cost> <pos> <semantic>  \
# 0        가나                  0                   0     0.0   NNG          *
# 1       가나슈                  0                   0     0.0   NNG          *
# 2        가또                  0                   0     0.0   NNG          *
# 3      가라아게                  0                   0     0.0   NNG          *
# 4     가라아게동                  0                   0     0.0   NNG          *
#
#   <has_jongseong> <reading> <type> <start_pos> <end_pos> <expression>
# 0               F        가나      *           *         *            *
# 1               F       가나슈      *           *         *            *
# 2               F        가또      *           *         *            *
# 3               T      가라아게      *           *         *            *
# 4               T     가라아게동      *           *         *            *

# %%
dict_notf['<has_jongseong>'] = dict_notf['<surface>'].apply(get_jongsung_TF)

# %%
dict_notf.head()
# Out:
#   <surface>  <left_context_id>  <right_context_id>  <cost> <pos> <semantic>  \
# 0        가나                  0                   0     0.0   NNG          *
# 1       가나슈                  0                   0     0.0   NNG          *
# 2        가또                  0                   0     0.0   NNG          *
# 3      가라아게                  0                   0     0.0   NNG          *
# 4     가라아게동                  0                   0     0.0   NNG          *
#
#   <has_jongseong> <reading> <type> <start_pos> <end_pos> <expression>
# 0               F        가나      *           *         *            *
# 1               F       가나슈      *           *         *            *
# 2               F        가또      *           *         *            *
# 3               T      가라아게      *           *         *            *
# 4               T     가라아게동      *           *         *            *

# %% [markdown]
# # 4. Save data

# %%
dict_notf.to_csv('/content/drive/MyDrive/menu_labelling/dictionaries/dict1_v1_1.csv',index=False)
