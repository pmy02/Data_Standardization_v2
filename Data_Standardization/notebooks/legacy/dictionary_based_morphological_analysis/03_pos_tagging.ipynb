# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 0. Install packages

# %%
# !pip install python-mecab-ko
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-mecab-ko
#   Downloading python_mecab_ko-1.3.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (575 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.6/575.6 KB 15.1 MB/s eta 0:00:00
# Collecting python-mecab-ko-dic
#   Downloading python_mecab_ko_dic-2.1.1.post2-py3-none-any.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 19.6 MB/s eta 0:00:00
# Installing collected packages: python-mecab-ko-dic, python-mecab-ko
# Successfully installed python-mecab-ko-1.3.3 python-mecab-ko-dic-2.1.1.post2

# %% [markdown]
# # 1. Load the user dictionary

# %%
# !python3 -m mecab dict-index --userdic nouns.dic '/content/drive/MyDrive/menu_labelling/dictionaries/dict3_v1_1.csv'
# Out:
# reading /content/drive/MyDrive/menu_labelling/박민영/dictionaries/dict3_v1_1.csv ... 398
# emitting double-array: 100% |###########################################|
#
# done!

# %% [markdown]
# # 2. Import packages and load data

# %%
import os
import pandas as pd
from mecab import MeCab
from tqdm import tqdm

# %%
data = pd.read_csv('/content/drive/MyDrive/menu_labelling/\'ㄷ\'으로 시작하는 데이터/d_filtered_preprocess.csv')

# %%
data.head()
# Out:
#        store                      MENU_NM 표준화상품명                     MENU_NM2  \
# 0  유이요거트_부천점                 (다크)HOT아메리카노  아메리카노                 (다크)HOT아메리카노
# 1  유이요거트_부천점  (다크)HOT아메리카노(오픈이벤트10월20일까지)  아메리카노  (다크)HOT아메리카노(오픈이벤트10월20일까지)
# 2  유이요거트_부천점            (다크)HOT아메리카노금액 할인  아메리카노            (다크)HOT아메리카노금액 할인
# 3  유이요거트_부천점                (다크)ICE 아메리카노  아메리카노                (다크)ICE 아메리카노
# 4  유이요거트_부천점                 (다크)ICE아메리카노  아메리카노                 (다크)ICE아메리카노
#
#                   MENU_NM3
# 0               다크HOT아메리카노
# 1  다크HOT아메리카노오픈이벤트10월20일까지
# 2          다크HOT아메리카노금액 할인
# 3              다크ICE 아메리카노
# 4               다크ICE아메리카노

# %% [markdown]
# # 3. POS tagging with MeCab

# %%
# Configure the user dictionary
mecab = MeCab(user_dictionary_path='nouns.dic')

# %%
# Function to extract only words from POS pairs
def str_to_pos(s):
  if s!="missing":
    poslist = mecab.pos(s)
    poses = [y[0] for y in poslist]
    return poses
  else:
    return []

# %%
# Apply the function to menu names
data['pos'] = data['MENU_NM3'].apply(str_to_pos)

# %%
data.head()
# Out:
#        store                      MENU_NM 표준화상품명                     MENU_NM2  \
# 0  유이요거트_부천점                 (다크)HOT아메리카노  아메리카노                 (다크)HOT아메리카노
# 1  유이요거트_부천점  (다크)HOT아메리카노(오픈이벤트10월20일까지)  아메리카노  (다크)HOT아메리카노(오픈이벤트10월20일까지)
# 2  유이요거트_부천점            (다크)HOT아메리카노금액 할인  아메리카노            (다크)HOT아메리카노금액 할인
# 3  유이요거트_부천점                (다크)ICE 아메리카노  아메리카노                (다크)ICE 아메리카노
# 4  유이요거트_부천점                 (다크)ICE아메리카노  아메리카노                 (다크)ICE아메리카노
#
#                   MENU_NM3                                            pos
# 0               다크HOT아메리카노                               [다크, HOT, 아메리카노]
# 1  다크HOT아메리카노오픈이벤트10월20일까지  [다크, HOT, 아메리카노, 오픈, 이, 벤트, 10, 월, 20, 일, 까지]
# 2          다크HOT아메리카노금액 할인                       [다크, HOT, 아메리카노, 금액, 할인]
# 3              다크ICE 아메리카노                               [다크, ICE, 아메리카노]
# 4               다크ICE아메리카노                               [다크, ICE, 아메리카노]

# %% [markdown]
# # 4. Add each POS result to the DataFrame

# %%
maxlen = data['pos'].apply(len).max()

# %%
tempdf = pd.DataFrame(data['pos'].tolist(),columns=[f'Pos{i+1}' for i in range(maxlen)])

# %%
resdf= pd.concat([data,tempdf],axis=1)

# %%
resdf.head()
# Out:
#        store                      MENU_NM 표준화상품명                     MENU_NM2  \
# 0  유이요거트_부천점                 (다크)HOT아메리카노  아메리카노                 (다크)HOT아메리카노
# 1  유이요거트_부천점  (다크)HOT아메리카노(오픈이벤트10월20일까지)  아메리카노  (다크)HOT아메리카노(오픈이벤트10월20일까지)
# 2  유이요거트_부천점            (다크)HOT아메리카노금액 할인  아메리카노            (다크)HOT아메리카노금액 할인
# 3  유이요거트_부천점                (다크)ICE 아메리카노  아메리카노                (다크)ICE 아메리카노
# 4  유이요거트_부천점                 (다크)ICE아메리카노  아메리카노                 (다크)ICE아메리카노
#
#                   MENU_NM3                                            pos  \
# 0               다크HOT아메리카노                               [다크, HOT, 아메리카노]
# 1  다크HOT아메리카노오픈이벤트10월20일까지  [다크, HOT, 아메리카노, 오픈, 이, 벤트, 10, 월, 20, 일, 까지]
# 2          다크HOT아메리카노금액 할인                       [다크, HOT, 아메리카노, 금액, 할인]
# 3              다크ICE 아메리카노                               [다크, ICE, 아메리카노]
# 4               다크ICE아메리카노                               [다크, ICE, 아메리카노]
#
#   Pos1 Pos2   Pos3  Pos4  ...  Pos9 Pos10 Pos11 Pos12 Pos13 Pos14 Pos15 Pos16  \
# 0   다크  HOT  아메리카노  None  ...  None  None  None  None  None  None  None  None
# 1   다크  HOT  아메리카노    오픈  ...    20     일    까지  None  None  None  None  None
# 2   다크  HOT  아메리카노    금액  ...  None  None  None  None  None  None  None  None
# 3   다크  ICE  아메리카노  None  ...  None  None  None  None  None  None  None  None
# 4   다크  ICE  아메리카노  None  ...  None  None  None  None  None  None  None  None
#
#   Pos17 Pos18
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None
#
# [5 rows x 24 columns]

# %%
resdf = resdf.drop('pos',axis=1)

# %% [markdown]
# # 5. Save data

# %%
resdf.to_csv('/content/drive/MyDrive/menu_labelling/\'ㄷ\'으로 시작하는 데이터/d_filtered_preprocess_dict1.csv',index=False)
